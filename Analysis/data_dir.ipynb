# %%
from pandas import read_csv
import re

# %%
df = read_csv('../dataset/symptoSense.csv')

# %%
features = df.drop('prognosis', axis=1).columns

pain_descriptors = [
    "dull", "sharp", "severe", "mild", "constant", "throbbing", "aching",
    "burning", "stabbing", "intense", "intermittent", "chronic", "acute"
]
negations = ["no", "not", "without"]

# %%
whitelist = set()
for feature in features:
    whitelist.update(feature.split())
whitelist.update(negations)
whitelist.update(pain_descriptors)

def remove_unnecessary_words(user_input):
    cleaned_words = [word for word in user_input.split() if word in whitelist]
    cleaned_input = ' '.join(cleaned_words)
    return cleaned_input

def match_symptom(user_input, feature_dict):
    cleaned_input = remove_unnecessary_words(user_input)

    if contains_negation(cleaned_input):
        print(f"Negation detected in input: '{cleaned_input}'")
        normalized_input = remove_descriptors(cleaned_input)
        for feature in feature_dict.keys():
            if normalized_input in feature:
                feature_dict[feature] = 0
    else:
        normalized_input = remove_descriptors(cleaned_input)
        for feature in feature_dict.keys():
            if normalized_input in feature:
                feature_dict[feature] = 1

    return feature_dict


def remove_descriptors(user_input):
    pattern = r'\b(' + '|'.join(pain_descriptors) + r')\b'
    cleaned_input = re.sub(pattern, '', user_input, flags=re.IGNORECASE).strip()
    return cleaned_input

def contains_negation(user_input):
    return any(negation in user_input for negation in negations)


def print_present_features(feature_dict):
    print("Present features (value 1):")
    for feature, value in feature_dict.items():
        if value == 1:
            print(f"{feature}: {value}")


print("Enter your symptoms one by one. Type 'done' when finished.")

while True:
    user_input = input("Enter symptom: ").lower().strip()
    
    if user_input == "done":
        print(user_input)
        break
    
    feature_dict = match_symptom(user_input, feature_dict)

print("\nUpdated feature dictionary:")
for feature, value in feature_dict.items():
    print(f"{feature}: {value}")

print_present_features(feature_dict)
# Out:
# Enter your symptoms one by one. Type 'done' when finished.
#
# Updated feature dictionary:
# abdominal distention: 0
# abnormal appearing skin: 0
# abnormal appearing tongue: 0
# abnormal breathing sounds: 1
# abnormal involuntary movements: 0
# abnormal movement of eyelid: 0
# abnormal size or shape of ear: 0
# absence of menstruation: 0
# abusing alcohol: 0
# ache all over: 0
# acne or pimples: 0
# allergic reaction: 0
# ankle stiffness or tightness: 0
# ankle weakness: 0
# antisocial behavior: 0
# anxiety and nervousness: 0
# apnea: 0
# arm cramps or spasms: 0
# arm lump or mass: 0
# arm pain: 0
# arm stiffness or tightness: 0
# arm swelling: 0
# arm weakness: 0
# back cramps or spasms: 0
# back mass or lump: 0
# back pain: 0
# back swelling: 0
# back weakness: 0
# bedwetting: 0
# bladder mass: 0
# bleeding from ear: 0
# bleeding from eye: 0
# bleeding gums: 0
# bleeding in mouth: 0
# bleeding or discharge from nipple: 0
# blindness: 0
# blood clots during menstrual periods: 0
# blood in stool: 0
# blood in urine: 0
# bones are painful: 0
# bowlegged or knock-kneed: 0
# breathing fast: 1
# bumps on penis: 0
# burning abdominal pain: 0
# burning chest pain: 1
# change in skin mole size or color: 0
# changes in stool appearance: 0
# chest tightness: 1
# chills: 0
# cloudy eye: 0
# congestion in chest: 1
# constipation: 0
# coryza: 0
# cough: 0
# coughing up sputum: 0
# cramps and spasms: 0
# cross-eyed: 0
# decreased appetite: 0
# decreased heart rate: 0
# delusions or hallucinations: 0
# depression: 0
# depressive or psychotic symptoms: 0
# diaper rash: 0
# diarrhea: 0
# difficulty breathing: 1
# difficulty eating: 0
# difficulty in swallowing: 0
# difficulty speaking: 0
# diminished hearing: 0
# diminished vision: 0
# discharge in stools: 0
# disturbance of memory: 0
# disturbance of smell or taste: 0
# dizziness: 0
# double vision: 0
# drainage in throat: 0
# drug abuse: 0
# dry lips: 0
# dry or flaky scalp: 0
# ear pain: 0
# early or late onset of menopause: 0
# elbow cramps or spasms: 0
# elbow lump or mass: 0
# elbow stiffness or tightness: 0
# elbow swelling: 0
# elbow weakness: 0
# emotional symptoms: 0
# excessive anger: 0
# excessive appetite: 0
# excessive growth: 0
# excessive urination at night: 0
# eye burns or stings: 0
# eye deviation: 0
# eye moves abnormally: 0
# eye redness: 0
# eye strain: 0
# eyelid lesion or rash: 0
# eyelid retracted: 0
# eyelid swelling: 0
# facial pain: 0
# fainting: 0
# fatigue: 0
# fears and phobias: 0
# feeling cold: 0
# feeling hot: 0
# feeling hot and cold: 0
# feeling ill: 0
# feet turned in: 0
# fever: 0
# flatulence: 0
# flu-like syndrome: 0
# fluid in ear: 0
# fluid retention: 0
# flushing: 0
# focal weakness: 0
# foot or toe cramps or spasms: 0
# foot or toe lump or mass: 0
# foot or toe pain: 0
# foot or toe stiffness or tightness: 0
# foot or toe swelling: 0
# foot or toe weakness: 0
# foreign body sensation in eye: 0
# frequent menstruation: 0
# frequent urination: 0
# frontal headache: 0
# groin mass: 0
# groin pain: 0
# gum pain: 0
# hand or finger cramps or spasms: 0
# hand or finger lump or mass: 0
# hand or finger pain: 0
# hand or finger stiffness or tightness: 0
# hand or finger swelling: 0
# hand or finger weakness: 0
# headache: 0
# heartburn: 0
# heavy menstrual flow: 0
# hemoptysis: 0
# hesitancy: 0
# hip lump or mass: 0
# hip pain: 0
# hip swelling: 0
# hip weakness: 0
# hoarse voice: 0
# hostile behavior: 0
# hot flashes: 0
# hurts to breath: 0
# hysterical behavior: 0
# impotence: 0
# incontinence of stool: 0
# increased heart rate: 0
# infant feeding problem: 0
# infant spitting up: 0
# infertility: 0
# infrequent menstruation: 0
# insomnia: 0
# intermenstrual bleeding: 0
# involuntary urination: 0
# irregular appearing nails: 0
# irregular appearing scalp: 0
# irregular belly button: 0
# irregular heartbeat: 0
# irritable infant: 0
# itchiness of eye: 0
# itching of scrotum: 0
# itching of skin: 0
# itching of the anus: 0
# itchy ear(s): 0
# itchy eyelid: 0
# itchy scalp: 0
# jaundice: 0
# jaw pain: 0
# jaw swelling: 0
# joint pain: 0
# joint stiffness or tightness: 0
# joint swelling: 0
# kidney mass: 0
# knee cramps or spasms: 0
# knee lump or mass: 0
# knee pain: 0
# knee stiffness or tightness: 0
# knee swelling: 0
# knee weakness: 0
# lack of growth: 0
# lacrimation: 0
# leg cramps or spasms: 0
# leg lump or mass: 0
# leg pain: 0
# leg stiffness or tightness: 0
# leg swelling: 0
# leg weakness: 0
# lip sore: 0
# lip swelling: 0
# long menstrual periods: 0
# loss of sensation: 0
# loss of sex drive: 0
# low back cramps or spasms: 0
# low back pain: 0
# low back stiffness or tightness: 0
# low back swelling: 0
# low back weakness: 0
# low self-esteem: 0
# low urine output: 0
# lower abdominal pain: 0
# lower body pain: 0
# lump in throat: 0
# lump or mass of breast: 0
# lump over jaw: 0
# lymphedema: 0
# mass in scrotum: 0
# mass on ear: 0
# mass on eyelid: 0
# mass on vulva: 0
# mass or swelling around the anus: 0
# melena: 0
# mouth dryness: 0
# mouth pain: 0
# mouth ulcer: 0
# muscle cramps, contractures, or spasms: 0
# muscle pain: 0
# muscle stiffness or tightness: 0
# muscle swelling: 0
# muscle weakness: 0
# nailbiting: 0
# nasal congestion: 0
# nausea: 0
# neck cramps or spasms: 0
# neck mass: 0
# neck pain: 0
# neck stiffness or tightness: 0
# neck weakness: 0
# nightmares: 0
# nose deformity: 0
# nosebleed: 0
# obsessions and compulsions: 0
# pain during intercourse: 0
# pain during pregnancy: 0
# pain in eye: 0
# pain in gums: 0
# pain in testicles: 0
# pain of the anus: 0
# pain or soreness of breast: 0
# painful menstruation: 0
# painful sinuses: 0
# painful urination: 0
# pallor: 0
# palpitations: 0
# paresthesia: 0
# pelvic pain: 0
# pelvic pressure: 0
# penile discharge: 0
# penis pain: 0
# penis redness: 0
# peripheral edema: 0
# plugged feeling in ear: 0
# polyuria: 0
# poor circulation: 0
# postpartum problems of the breast: 0
# posture problems: 0
# premature ejaculation: 0
# premenstrual tension or irritability: 0
# problems during pregnancy: 0
# problems with movement: 0
# problems with orgasm: 0
# problems with shape or size of breast: 0
# pulling at ears: 0
# pupils unequal: 0
# pus draining from ear: 0
# pus in sputum: 0
# pus in urine: 0
# recent pregnancy: 0
# recent weight loss: 0
# rectal bleeding: 0
# redness in ear: 0
# redness in or around nose: 0
# regurgitation: 0
# restlessness: 0
# retention of urine: 0
# rib pain: 0
# ringing in ear: 0
# scanty menstrual flow: 0
# seizures: 0
# sharp abdominal pain: 0
# sharp chest pain: 1
# shortness of breath: 0
# shoulder cramps or spasms: 0
# shoulder lump or mass: 0
# shoulder pain: 0
# shoulder stiffness or tightness: 0
# shoulder swelling: 0
# shoulder weakness: 0
# side pain: 0
# sinus congestion: 0
# skin dryness, peeling, scaliness, or roughness: 0
# skin growth: 1
# skin irritation: 0
# skin lesion: 0
# skin moles: 0
# skin oiliness: 0
# skin on arm or hand looks infected: 0
# skin on head or neck looks infected: 0
# skin on leg or foot looks infected: 0
# skin pain: 0
# skin rash: 0
# skin swelling: 0
# sleepiness: 0
# sleepwalking: 0
# slurring words: 0
# smoking problems: 0
# sneezing: 0
# sore in nose: 0
# sore throat: 0
# spots or clouds in vision: 0
# spotting or bleeding during pregnancy: 0
# stiffness all over: 0
# stuttering or stammering: 0
# suprapubic pain: 0
# sweating: 0
# swelling of scrotum: 0
# swollen abdomen: 0
# swollen eye: 0
# swollen lymph nodes: 0
# swollen or red tonsils: 0
# swollen tongue: 0
# symptoms of bladder: 0
# symptoms of eye: 0
# symptoms of infants: 0
# symptoms of prostate: 0
# symptoms of the face: 0
# symptoms of the kidneys: 0
# symptoms of the scrotum and testes: 0
# temper problems: 0
# thirst: 0
# throat feels tight: 0
# throat irritation: 0
# throat redness: 0
# throat swelling: 0
# tongue bleeding: 0
# tongue lesions: 0
# tongue pain: 0
# too little hair: 0
# toothache: 0
# underweight: 0
# unpredictable menstruation: 0
# unusual color or odor to urine: 0
# unwanted hair: 0
# upper abdominal pain: 0
# uterine contractions: 0
# vaginal bleeding after menopause: 0
# vaginal discharge: 0
# vaginal dryness: 0
# vaginal itching: 0
# vaginal pain: 0
# vaginal redness: 0
# vomiting: 0
# vomiting blood: 0
# vulvar irritation: 0
# vulvar sore: 0
# warts: 0
# weakness: 0
# weight gain: 0
# wheezing: 0
# white discharge from eye: 0
# wrinkles on skin: 0
# wrist lump or mass: 0
# wrist stiffness or tightness: 0
# wrist swelling: 0
# Present features (value 1):
# abnormal breathing sounds: 1
# breathing fast: 1
# burning chest pain: 1
# chest tightness: 1
# congestion in chest: 1
# difficulty breathing: 1
# sharp chest pain: 1
# skin growth: 1

# %%
# Out:
# ['I have chest pain', ' I have pain in kidney', ' What should I do?']
